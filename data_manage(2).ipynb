# %%
import pandas as pd
import random

def random_float():
    return random.uniform(0.00, 1.00)

# %%
df = pd.read_excel('DraftPickHeroML.xlsx')

# %%
hero_col = list(df.columns)[2:]

# %%
for hero in hero_col:
    df[hero] = [random_float() for i in range(len(df))]

# %%
df.head()
# Out:
#          Tim   Player    Claude     Kufra    Kadita   Beatrix       Yve  \
# 0  Alter Ego      Pai  0.386353  0.812982  0.107052  0.619890  0.096451
# 1  Alter Ego     Udil  0.198554  0.359033  0.790925  0.022366  0.877614
# 2  Alter Ego  Celiboy  0.991807  0.912791  0.528539  0.190616  0.570974
# 3  Alter Ego     Rasy  0.777823  0.493218  0.848698  0.887928  0.691226
# 4  Alter Ego     Nino  0.711908  0.958292  0.833837  0.371533  0.048205
#
#       Baxia  Fredrynn   Paquito  ...  Minotaur  Minsitar   Novaria   Rafaela  \
# 0  0.722843  0.402116  0.687159  ...  0.981080  0.003774  0.171524  0.778609
# 1  0.275135  0.345385  0.162037  ...  0.619233  0.567728  0.405742  0.337555
# 2  0.653794  0.020372  0.337475  ...  0.996847  0.333902  0.167347  0.478701
# 3  0.915164  0.224711  0.936689  ...  0.246218  0.527152  0.643789  0.625604
# 4  0.721862  0.392411  0.870106  ...  0.854492  0.294081  0.102649  0.911350
#
#        Ruby     Saber    Selena  Valentina     Valir    Wanwan
# ...

# %%
df.to_excel('DraftPickHeroML(res).xlsx', index=False)
